# %% [markdown]
# <a href="https://colab.research.google.com/github/davisbyun/ai/blob/%2Bpython/7_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 데이터프레임

# %%
import pandas as pd

# %%
list1 = list(  [  ['한빛', '남자', '20', '180'], ['한결', '남자', '21', '177'], ['한라', '여자', '20', '160']  ]  )
col_names =  [ '이름', '성별', '나이', '키' ]
df1 = pd.DataFrame( list1, columns=col_names )
df1
df2 = pd.DataFrame( list1, index=['1반','2반','3반'] , columns=col_names )
df2
df2.index
df2.values
df2.value_counts()
# Out:
# 이름  성별  나이  키
# 한결  남자  21  177    1
# 한라  여자  20  160    1
# 한빛  남자  20  180    1
# dtype: int64

# %%
dict1 = {'이름' : {0:'한빛', 1:'한결', 2:'한라'}, '성별':{0:'남자', 1:'남자', 2:'여자'}, '나이':{0:'20', 1:'21', 2:'20'}, '키':{0:'180', 1:'177', 2:'160'}}
df2 = pd.DataFrame(dict1)
df2
# Out:
#    이름  성별  나이    키
# 0  한빛  남자  20  180
# 1  한결  남자  21  177
# 2  한라  여자  20  160

# %%
list1 = list([['허준호','남자','30','183'],
 	['이가원','여자','24','162'],
 	['배규민','남자','23','179'],
 	['고고림','남자','21','182']])
col_names = ['이름','성별','나이','키']
df = pd.DataFrame(list1, columns=col_names)
df
# Out:
#     이름  성별  나이    키
# 0  허준호  남자  30  183
# 1  이가원  여자  24  162
# 2  배규민  남자  23  179
# 3  고고림  남자  21  182

# %%
dic2={'이름':{0:'허준호', 1:'이기원', 2:'배규민', 3:'고고림'},
          '성별':{0:'남자', 1:"여자", 2:'남자', 3:'남자'},
          '나이':{0:'30', 1:'23', 2:'23', 3:'21' },
          '키':{0:'183', 1:'162', 2:'179',3:'182' }
}

col_names=['이름','성별','나이','키']
df3=pd.DataFrame(dic2)
df3
df3.to_csv('df3.csv',  header=True, index=False , encoding='cp949'  )  # 파일을 여러가지 확장자로 받을 수 있다. df3.to
df3.to_excel('df3.xlsx', header=True, index=False , encoding='cp949')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
# 외부에서 iris.csv 데이터셋 불러오기
#df4 = pd.read_csv('df3.csv', sep=',', decode='cpc949' )

#방법1) 다운받아서 코랩에 올려주기
#from google.colab import files
#f=files.upload()
# iris_df = pd.read_csv( 'iris.csv', sep=',', encoding='cp949' )
# iris_df
#방법2) 다운 받을 url을 써주면 콜랩에서 올려줌 - github는 raw를 누르고 그것의 링크를 복사
iris_url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
iris_df = pd.read_csv( iris_url, sep=',', encoding='cp949'  )
iris_df
#vgsales.csv 파일을 찾아서 넣기
vgsales_url = 'https://raw.githubusercontent.com/raghav-19/Video-Games-Sales-Data-Analysis/master/vgsales.csv'
vgsales_df = pd.read_csv( vgsales_url, sep=',', encoding='utf-8' )
vgsales_df
# Out:
#                                Name Platform    Year     Genre  \
# 0                           Kaboom!     2600  1980.0      Misc
# 1                            Boxing     2600  1980.0  Fighting
# 2                        Ice Hockey     2600  1980.0    Sports
# 3                           Freeway     2600  1980.0    Action
# 4                            Bridge     2600  1980.0      Misc
# ...                             ...      ...     ...       ...
# 16534  LEGO Harry Potter: Years 5-7       PC     NaN    Action
# 16535                Happy Feet Two       DS     NaN    Action
# 16536                Happy Feet Two      PS3     NaN    Action
# 16537                Happy Feet Two     X360     NaN    Action
# 16538                Happy Feet Two      Wii     NaN    Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0                                  Activision      1.07      0.07       0.0
# ...

# %%
#  데이터 프레임 만들기
# list를 이용해서 만들기
list1 = [ [ 'KFC',  1000, 4.5],
             [ 'McDonald',  2000, 3.9],
             [ 'SchoolFood',  2500, 4.2],
          ]
col_names = [ 'food', 'price', 'rating' ]
df1 = pd.DataFrame( list1, col_names )
df1
# Out:
#                  0     1    2
# food           KFC  1000  4.5
# price     McDonald  2000  3.9
# rating  SchoolFood  2500  4.2

# %% [markdown]
# #카페문제 2878

# %%
# 딕셔너리를 이용해서 만들기
dic1 = {  'food' : { 0:'KFC', 1: 'McDonald', 2:'SchoolFood' } ,
              'price' : { 0:1000, 1: 2000, 2:2500} ,
              'rating' : { 0:4.5, 1: 3.9, 2:4.2}
          }
df2 = pd.DataFrame( dic1 )
df2
df2[ [  'food' , 'rating'  ]   ]
df2[   'food'  ]   # [   열이름 ]  결과를 시리즈로 보기
df2[   [ 'food']   ]  # [ [ 열이름 ]]  결과를 데이터프레임 보기
df2.rename( columns={ 'food' : 'place'  }, inplace=True)
df2
# Out:
#         place  price  rating
# 0         KFC   1000     4.5
# 1    McDonald   2000     3.9
# 2  SchoolFood   2500     4.2

# %% [markdown]
# #카페문제 2879

# %%
# 1. 다음 데이터프레임에서 현재가가 1500 이상인 값만 가져와보세요

data = [
    ["037730", "3R", 1510, 7.36],
    ["036360", "3SOFT", 1790, 1.65],
    ["005760", "ACTS", 1185, 1.28],
]
columns = ["종목코드", "종목명", "현재가", "등락률"]
df = pd.DataFrame(data=data, columns=columns)
df.set_index('종목코드', inplace=True)
df
# Out:
#           종목명   현재가   등락률
# 종목코드
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
df [df[ '현재가' ] >=1500 ]
df1=( df[ '현재가' ] >=1500 ) & ( df['현재가']<1700 )
df[df1]
# Out:
#        종목명   현재가   등락률
# 종목코드
# 037730  3R  1510  7.36

# %%
df['목표가']=df['현재가']*0.01
df
# Out:
#           종목명   현재가   등락률    목표가
# 종목코드
# 037730     3R  1510  7.36  15.10
# 036360  3SOFT  1790  1.65  17.90
# 005760   ACTS  1185  1.28  11.85

# %%
#loc명령어 - 행에 대한 자료를 추가하거나 검색할 때 사용
df.loc['066570'] = ['LG전자', 60000,3.84,60000*0.01  ]
#df.loc[인덱스번호] =['값들'] (행추가됨)
df

#df.loc['037730']
# Out:
#           종목명    현재가   등락률     목표가
# 종목코드
# 037730     3R   1510  7.36   15.10
# 036360  3SOFT   1790  1.65   17.90
# 005760   ACTS   1185  1.28   11.85
# 066570   LG전자  60000  3.84  600.00

# %%
# 다음 코드를 통해 데이터프레임을 생성합니다.
df5= pd.DataFrame(data = [[1, 2, 3], [4, 5, 6]], columns=["A", "B", "C"])
df5
# 생성된 데이터프레임에서 columns 속성을 사용하여 컬럼명을 'a', 'b', 'c'로 변경하세요.
df5.columns=['a','b','c']
df5
df5.rename (columns={'a':'가', 'b':'나','c':'다'}, inplace=True )
df5
# Out:
#    가  나  다
# 0  1  2  3
# 1  4  5  6

# %%
#6 생략

# %%
#7.  name 속성
# 다음 데이터프레임의 index의 name 속성을 'year'로 columns의 name 속성을 'company'로 변경하세요.

import pandas as pd
import numpy as np

data = {"카카오": [np.nan, 221, 35], "NAVER": [52, 47, 3]}
index = [2019, 2020, 2021]
df7 = pd.DataFrame(data=data, index=index)
df7
df7.index.dtype
print(df7.columns.name,'~~')
df7.index.name='year'
df7.columns.name='company'
print(df7.index.name)
print(df7.columns.name)
df7.index.dtype
# Out:
# None ~~
# year
# company
# dtype('int64')

# %%
# 8.  데이터프레임 reindex

# 다음 데이터프레임에서 컬럼의 순서를 ['NAVER', '카카오']로 재정렬해보세요.

data = {"카카오": [np.nan, 221, 35], "NAVER": [52, 47, 3]}
index = [2019, 2020, 2021]
df8 = pd.DataFrame(data=data, index=index)
df8
# Out:
#         카카오  NAVER
# 2019    NaN     52
# 2020  221.0     47
# 2021   35.0      3

# %%
# 9.  데이터프레임 drop
# 다음 데이터프레임에서 '카카오'와 'NAVER' 컬럼을 삭제하세요.
data = {"카카오": [np.nan, 221, 35], "NAVER": [52, 47, 3]}
index = [2019, 2020, 2021]
df8 = df.drop("NAVER", axis='columns')
df8 = df.drop("카카오", axis=1)
df8 = df.drop(["카카오","NAVER"], axis=1 )

# %%
#10.  DataFrame dropna
#다음 데이터프레임에서 np.nan 값이 있는 모든 행을 제거하세요.
data = [
    [1, 2, 3],
    [np.nan, 5, 6],
    [7, np.nan, 9],
    [10, 11, np.nan]
]
df10 = pd.DataFrame(data)
df10
df10.dropna()  #dropna 명령어 사용
# Out:
#      0    1    2
# 0  1.0  2.0  3.0

# %%
# 11.  dataframe.dropna (subset)
# 다음 데이터프레임에서 col2 컬럼의 값에 NaN이 포함된 행만 제거하세요.
# import pandas as pd
# import numpy as np

data = [
    [1, 1, np.nan],
    [10, np.nan, 10],
    [2, 3, 4]
]
columns = ['col0', 'col1', 'col2']
df11 = pd.DataFrame(data, columns=columns)
df11
df11.dropna(subset = 'col2') #col2의 결측값이 있는 행만 지움
# Out:
#    col0  col1  col2
# 1    10   NaN  10.0
# 2     2   3.0   4.0

# %%
# 12.  dataframe.fillna

# 다음 데이터프레임의 NaN 값을 0으로 채우세요.

# import pandas as pd
# import numpy as np

data = [
    [1, 1, np.nan],
    [10, np.nan, 10],
    [2, 3, 4]
]
columns = ['col0', 'col1', 'col2']
df12 = pd.DataFrame(data, columns=columns)
df12
#fillna(0) NaN값을 0으로 채움
df12.fillna(0)
# Out:
#    col0  col1  col2
# 0     1   1.0   0.0
# 1    10   0.0  10.0
# 2     2   3.0   4.0

# %%
# 13. dataframe replace

# 다음 데이터프레임에서 0을 100으로 변경하세요.

# import pandas as pd
# import numpy as np

data = [
    [1, 1, np.nan],
    [10, np.nan, 10],
    [2, 3, 4]
]
columns = ['col0', 'col1', 'col2']
df13 = pd.DataFrame(data, columns=columns)
df13 =df13.fillna(0)
df13.replace(0,100)
# Out:
#    col0   col1   col2
# 0     1    1.0  100.0
# 1    10  100.0   10.0
# 2     2    3.0    4.0

# %%
#14.  DataFrame.query (14~18)
# 데이터프레임 query 메서드를 사용하여 종가(close)가 시가(open)보다 큰 데이터만 가져오세요.
data = [
    {"cd":"A060310", "nm":"3S", "open":2920, "close":2800},
    {"cd":"A095570", "nm":"AJ네트웍스", "open":1920, "close":1900},
    {"cd":"A006840", "nm":"AK홀딩스", "open":2020, "close":2010},
    {"cd":"A054620", "nm":"APS홀딩스", "open":3120, "close":3200}
]
df14 = pd.DataFrame(data=data)
df14 = df14.set_index('cd')
df14
df14.query('open<close')
#15 위 데이터프레임에서 종가(close)가 3,000원 이상인 종목만 출력하세요.
df14.query('close>=3000')
#16.위 데이터프레임에서 시가(open)가 2,000원 이상이고 종가(close)가 시가(open)이상인 종목을 출력하세요.
df14.query(('open>=2000 ') and ('close>=open'))
#17. query 와 str.startswith
#위 데이터프레임에서 종목명(nm)이 'A'로 시작하는 종목만 선택하세요.
df14.query( "nm.str.startswith('A')" )
#18. query 와 str.contains
# 위 데이터프레임에서 종목명에 '홀딩스'가 포함된 종목만 선택하세요.
df14.query( "nm.str.contains('홀딩스') ")
#'스'로  끝나는 것
df14.query( "nm.str.endswith('스')" )
# Out:
#              nm  open  close
# cd
# A095570  AJ네트웍스  1920   1900
# A006840   AK홀딩스  2020   2010
# A054620  APS홀딩스  3120   3200

# %%
# 19.  DataFrame filter
# 다음 데이터프레임에서 filter 메서드를 사용해서 "PER"과 "PBR" 컬럼만 선택하세요.
data = {
    "PER": [6.42, 17.63, 21.09, 13.93],
    "PBR": [1.10, 1.49, 2.06, 1.88],
    "DPS": [1416, 1716, 2994, 1755]
}
index = ["2019/12", "2020/12", "2021/12", "2022/12(E)"]
df19 = pd.DataFrame(data=data, index=index)
df19=df19.filter(items=["PER", "PBR"])
df19=df19.filter(regex='R$', axis=1)
df.filter(like='R', axis=0)
df19
# Out:
#               PER   PBR
# 2019/12      6.42  1.10
# 2020/12     17.63  1.49
# 2021/12     21.09  2.06
# 2022/12(E)  13.93  1.88

# %%
#21 위 데이터프레임에서 filter 메서드를 사용해서 예상치인 '2022/12(E)'를 제외한 나머지 로우 데이터를 선택하세요.
df19=df19.filter(regex='12$', axis=0)
df19
# Out:
# Empty DataFrame
# Columns: []
# Index: [2019/12, 2020/12, 2021/12]

# %%
# 22. 데이터프레임 filter like
# 위 데이터프레임에서 "2022"년 데이터만 선택하세요. 2022년 데이터는 인덱스에 '2022'라는 문자열이 포함되어있습니다.
df19.filter(like='2022', axis=0)

# %% [markdown]
# #데이터프레임 문제 3 #2880

# %%
# df1, df2 데이터프레임을 위/아래 방향으로 연결하세요. (위에 df1이 있고 그 아래에 df2가 있어야합니다.)

from datetime import datetime

columns = ['open', 'high', 'low', 'close']
index1 = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7),
    datetime(2022, 9, 6),
    datetime(2022, 9, 5),
    datetime(2022, 9, 2)
]

index2 = [
    datetime(2022, 9, 1),
    datetime(2022, 8, 31),
    datetime(2022, 8, 30),
    datetime(2022, 8, 29),
    datetime(2022, 8, 26)
]

df1 = pd.DataFrame(data=np.arange(0, 20).reshape(5,4), index=index1, columns=columns)
df2 = pd.DataFrame(data=np.arange(20,40).reshape(5,4), index=index2, columns=columns)
# Out:
#             open  high  low  close
# 2022-09-08     0     1    2      3
# 2022-09-07     4     5    6      7
# 2022-09-06     8     9   10     11
# 2022-09-05    12    13   14     15
# 2022-09-02    16    17   18     19

# %%
# 2.  데이터터프레임 위/아래 붙이기 (concat)
pd.concat([df1,df2], axis=0 )
# 위 df1, df2 데이터프레임을 위/아래 방향으로 연결하세요. (위에 df2가 있고 그 아래에 df1가 있어야합니다.)
pd.concat([df2,df1], axis=0 )
#3.  데이터프레임 좌/우로 붙이기 (concat)
#다음 df1, df2 데이터프레임을 좌/우로 붙여 새로운 데이터프레임을 생성하세요.
pd.concat([df1,df2], axis=1 ) #full outter join이 됨
# Out:
#             open  high   low  close  open  high   low  close
# 2022-08-26   NaN   NaN   NaN    NaN  36.0  37.0  38.0   39.0
# 2022-08-29   NaN   NaN   NaN    NaN  32.0  33.0  34.0   35.0
# 2022-08-30   NaN   NaN   NaN    NaN  28.0  29.0  30.0   31.0
# 2022-08-31   NaN   NaN   NaN    NaN  24.0  25.0  26.0   27.0
# 2022-09-01   NaN   NaN   NaN    NaN  20.0  21.0  22.0   23.0
# 2022-09-02  16.0  17.0  18.0   19.0   NaN   NaN   NaN    NaN
# 2022-09-05  12.0  13.0  14.0   15.0   NaN   NaN   NaN    NaN
# 2022-09-06   8.0   9.0  10.0   11.0   NaN   NaN   NaN    NaN
# 2022-09-07   4.0   5.0   6.0    7.0   NaN   NaN   NaN    NaN
# 2022-09-08   0.0   1.0   2.0    3.0   NaN   NaN   NaN    NaN

# %%
index = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7),
    datetime(2022, 9, 6),
    datetime(2022, 9, 5),
    datetime(2022, 9, 2)
]

df1 = pd.DataFrame(data=np.arange(0, 10).reshape(5,2), index=index, columns=['open', 'high'])
df2 = pd.DataFrame(data=np.arange(10,20).reshape(5,2), index=index, columns=['low', 'close'])
pd.concat([df1,df2], axis=1)
# Out:
#             open  high  low  close
# 2022-09-08     0     1   10     11
# 2022-09-07     2     3   12     13
# 2022-09-06     4     5   14     15
# 2022-09-05     6     7   16     17
# 2022-09-02     8     9   18     19

# %%
#4. DataFrame.concat

#다음 df1, df2 데이터프레임을 위/아래로 연결하세요. concat 메서드에서 join='outer'를 사용하세요.
from datetime import datetime

index1 = [
    datetime(2022, 9, 8),
    datetime(2022, 9, 7)
]

index2 = [
    datetime(2022, 9, 6),
    datetime(2022, 9, 5)
]
df1 = pd.DataFrame(np.arange(0, 6).reshape(2,3), index=index1, columns=['open', 'high', 'low'])
df2 = pd.DataFrame(np.arange(6,12).reshape(2,3), index=index2, columns=['high', 'low', 'close'])
df1
pd.concat([df1,df2],join='outer')
#7
pd.concat((['s1','s2'], axis=1))

#8
df1=pd.DataFrame(np.arange(0,4)), reshape(2,2))
df1=pd.DataFrame(np.arange(4,8)), reshape(2,2))
# Out:
#   File "<ipython-input-13-a83ab462978c>", line 20
#     pd.concat((['s1','s2'], axis=1))
#                             ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
s1=pd.Series(['a','b'])
s2=pd.Series(['c','d'])
pd.concat([s1,s2])
# Out:
# 0    a
# 1    b
# 0    c
# 1    d
# dtype: object

# %%
data = [
    ["2차전지(생산)", "SK이노베이션", 10.19, 1.29],
    ["해운", "팬오션", 21.23, 0.95],
    ["시스템반도체", "티엘아이", 35.97, 1.12],
    ["해운", "HMM", 21.52, 3.20],
    ["시스템반도체", "아이에이", 37.32, 3.55],
    ["2차전지(생산)", "LG화학", 83.06, 3.75]
]

columns = ["테마", "종목명", "PER", "PBR"]
df9 = pd.DataFrame(data=data, columns=columns)
df9
# Out:
#          테마      종목명    PER   PBR
# 0  2차전지(생산)  SK이노베이션  10.19  1.29
# 1        해운      팬오션  21.23  0.95
# 2    시스템반도체     티엘아이  35.97  1.12
# 3        해운      HMM  21.52  3.20
# 4    시스템반도체     아이에이  37.32  3.55
# 5  2차전지(생산)     LG화학  83.06  3.75

# %%
#10. DataFrame.groupby max, min
#위 데이터프레임에서 테마별 PER, PBR의 최대, 최소값을 계산하세요.
df9.groupby(by='테마').mean() #테마별평균
df9.groupby(by='테마').sum()
df9.groupby(by='테마').max()
df9.groupby(by='테마').min()
df9.groupby(by='테마').size()
# Out:
# <ipython-input-21-439d24d44f28>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df9.groupby(by='테마').mean() #테마별평균
# <ipython-input-21-439d24d44f28>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df9.groupby(by='테마').sum()
# 테마
# 2차전지(생산)    2
# 시스템반도체      2
# 해운          2
# dtype: int64

# %%
#12. DataFrame.groupby get_group
#위 데이터프레임을 '테마' 컬럼으로 그룹핑한 후 '2차전지(생산)' 그룹만 가져오세요.
gb1=df9.groupby(by='테마')
gb1.get_group('2차전지(생산)').max()
# Out:
# 테마     2차전지(생산)
# 종목명     SK이노베이션
# PER       83.06
# PBR        3.75
# dtype: object

# %%
#13. DataFrame groupby
#위 데이터프레임에서 테마별 PER의 평균을 계산하세요.
df9.groupby(by='테마').mean()[['PER']]
# Out:
# <ipython-input-23-3ec01141534c>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df9.groupby(by='테마').mean()[['PER']]
#              PER
# 테마
# 2차전지(생산)  46.625
# 시스템반도체    36.645
# 해운        21.375

# %%
#14.  DataFrame.groupby 슬라이싱
#위 데이터프레임에 대해 테마로 그룹화한 후 PER, PBR 컬럼을 슬라이싱하세요. 그 다음 두 컬럼에 대한 평균을 계산하세요.

#시스템 반도체 행만 보이기
df9_g.loc[['시스템반도체']]
# Out:
#            PER    PBR
# 테마
# 시스템반도체  36.645  2.335

# %%
#15. DataFrame.groupby agg
#위 데이터프레임에 대해서 '테마' 컬럼으로 그룹화한 후 max 함수를 적용하세요.
df9.groupby(by='테마').agg(max)
# Out:
#               종목명    PER   PBR
# 테마
# 2차전지(생산)  SK이노베이션  83.06  3.75
# 시스템반도체       티엘아이  37.32  3.55
# 해운            팬오션  21.52  3.20

# %%
#16. DataFrame.groupby agg
#위 데이터프레임에 대해서 '테마' 컬럼으로 그룹화한 후 PER 컬럼은 max, PBR 컬럼은 min 함수를 적용해보세요.
df9.groupby(by='테마').agg({'PER':max, 'PBR':min})
# Out:
#             PER   PBR
# 테마
# 2차전지(생산)  83.06  1.29
# 시스템반도체    37.32  1.12
# 해운        21.52  0.95

# %%
#17. Group 순회
#위 데이터프레임에 대해 '테마'로 그룹화 한 후 순회하는 다음 코드를 실행하고 결과를 확인하세요. 아래코드 실행해서 결과 보세요.
for name, group in df.groupby("테마"):
    print(name)
    print(group)
# Out:
# 2차전지(생산)
#          테마      종목명    PER   PBR
# 0  2차전지(생산)  SK이노베이션  10.19  1.29
# 5  2차전지(생산)     LG화학  83.06  3.75
# 시스템반도체
#        테마   종목명    PER   PBR
# 2  시스템반도체  티엘아이  35.97  1.12
# 4  시스템반도체  아이에이  37.32  3.55
# 해운
#    테마  종목명    PER   PBR
# 1  해운  팬오션  21.23  0.95
# 3  해운  HMM  21.52  3.20

# %%
#18. groupby agg
#위 데이터프레임에 대해서 '테마' 컬럼으로 그룹화한 후 PER, PBR 컬럼에 np.mean과 np.std 함수를 적용하세요.
df9.groupby(by='테마')[['PER','PBR']].agg([np.mean, np.std])
# Out:
#              PER               PBR
#             mean        std   mean       std
# 테마
# 2차전지(생산)  46.625  51.526871  2.520  1.739483
# 시스템반도체    36.645   0.954594  2.335  1.718269
# 해운        21.375   0.205061  2.075  1.590990

# %%
#19. nunique
#위 데이터프레임을 '테마' 컬럼을 기준으로 그룹화한 후 종목명 열만 추출하여 데이터의 빈도수를 계산하세요.
df9.groupby(by='테마')['종목명'].nunique()
# Out:
# 테마
# 2차전지(생산)    2
# 시스템반도체      2
# 해운          2
# Name: 종목명, dtype: int64

# %% [markdown]
# #groupby 문제 추가

# %%
from IPython.display import Image
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #컬럼(columns) 설명
#
# - survivied: 생존여부 (1: 생존, 0: 사망)
# - pclass: 좌석 등급 (1등급, 2등급, 3등급)
# - sex: 성별
# - age: 나이
# - sibsp: 형제 + 배우자 수
# - parch: 부모 + 자녀 수
# - fare: 좌석 요금
# - embarked: 탑승 항구 (S, C, Q)
# - class: pclass와 동일
# - who: 남자(man), 여자(woman), 아이(child)
# - adult_male: 성인 남자 여부
# - deck: 데크 번호 (알파벳 + 숫자 혼용)
# - embark_town: 탑승 항구 이름
# - alive: 생존여부 (yes, no)
# - alone: 혼자 탑승 여부

# %%
df['who']
# Out:
# 0        man
# 1      woman
# 2      woman
# 3      woman
# 4        man
#        ...
# 886      man
# 887    woman
# 888    woman
# 889      man
# 890      man
# Name: who, Length: 891, dtype: object

# %%
df['who'].value_counts()
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
#사용자함수 만들기
def transform_who(x) :
  if x=='man' :
    return '남자'
  elif x=='woman'  :
    return '여자'
  else :
    return '아이'
df['who'].apply(transform_who) #사용자가 정의한 함수를 호출해 준다. appy(사용자함수명)
df['who'].apply(transform_who).value_counts()
# Out:
# 남자    537
# 여자    271
# 아이     83
# Name: who, dtype: int64

# %%
#좌석요금: fare  나이 : age
#구하려는 값은 (좌석요금/나이) 모든 행에 대해 구하라.
def tr_fare_age(x) :
  return x['fare'] / x['age']
  aa = df.apply(tr_fare_age, axis=1)
  aa

# %%
#문제 타이타닉호의 생존자와 사망자를 성별 기준으로 그룹핑하여 평균을 살펴보기
df.groupby(by='sex').mean()
# Out:
# <ipython-input-55-b0e1f64f95b9>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by='sex').mean()
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
#문제 성별, 좌석등급별 통계 평균구하기
df.groupby(['sex','pclass']).mean()
# Out:
# <ipython-input-59-93eb894aa8be>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['sex','pclass']).mean()
#                survived        age     sibsp     parch        fare  \
# sex    pclass
# female 1       0.968085  34.611765  0.553191  0.457447  106.125798
#        2       0.921053  28.722973  0.486842  0.605263   21.970121
#        3       0.500000  21.750000  0.895833  0.798611   16.118810
# male   1       0.368852  41.281386  0.311475  0.278689   67.226127
#        2       0.157407  30.740707  0.342593  0.222222   19.741782
#        3       0.135447  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    pclass
# female 1         0.000000  0.361702
#        2         0.000000  0.421053
#        3         0.000000  0.416667
# ...

# %%
df.groupby(['pclass','sex']).mean()
# Out:
# <ipython-input-61-6ef75d3d4fc6>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['pclass','sex']).mean()
#                survived        age     sibsp     parch        fare  \
# pclass sex
# 1      female  0.968085  34.611765  0.553191  0.457447  106.125798
#        male    0.368852  41.281386  0.311475  0.278689   67.226127
# 2      female  0.921053  28.722973  0.486842  0.605263   21.970121
#        male    0.157407  30.740707  0.342593  0.222222   19.741782
# 3      female  0.500000  21.750000  0.895833  0.798611   16.118810
#        male    0.135447  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# pclass sex
# 1      female    0.000000  0.361702
#        male      0.975410  0.614754
# 2      female    0.000000  0.421053
# ...

# %%
#문제 성별, 좌석등급별 통계 평균구하기 survived 열만 보기
df.groupby(['pclass','sex']).mean()[['survived']] # 모든 것을 구하고 해당 컬럼의 평균을 구함
# Out:
# <ipython-input-62-82bd758e1874>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['pclass','sex']).mean()[['survived']]
#                survived
# pclass sex
# 1      female  0.968085
#        male    0.368852
# 2      female  0.921053
#        male    0.157407
# 3      female  0.500000
#        male    0.135447

# %%
df.groupby(['pclass','sex'])[['survived']].mean() #필요한 컬럼만 추출하고 계산(더 잘 만든 코드임)
# Out:
#                survived
# pclass sex
# 1      female  0.968085
#        male    0.368852
# 2      female  0.921053
#        male    0.157407
# 3      female  0.500000
#        male    0.135447

# %%
#문제 성별, 좌석등급, 생존자를 0~5까지 인덱스번호가 만들어지고 표(데이터프레임)처럼 출력
df.groupby(['sex','pclass'])[['survived']].mean().reset_index()
# Out:
#       sex  pclass  survived
# 0  female       1  0.968085
# 1  female       2  0.921053
# 2  female       3  0.500000
# 3    male       1  0.368852
# 4    male       2  0.157407
# 5    male       3  0.135447

# %%
#생존율은 평균, 나이 합계 구하기
df.groupby(['sex','pclass'])([['survived' , 'age'],[mean,sum] ])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-e8336f10fcb5> in <cell line: 2>()
#       1 #생존율은 평균, 나이 합계 구하기
# ----> 2 df.groupby(['sex','pclass'])([['survived' , 'age'],[mean,sum] ])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     963             from pandas.core.groupby.grouper import get_grouper
#     964
# --> 965             grouper, exclusions, obj = get_grouper(
# ...

# %% [markdown]
# #데이터프레임 문제4 카페문제

# %%
import pandas as pd

data = [
    ['Multiples', 'PER', 21.09, 13.55],
    ['Multiples', 'PBR', 2.06, 1.80],
    ['Dividends', 'DPS', 2944, 1444],
    ['Dividends', '배당성향', 78, 25]
]
columns = ['Category', 'Factor', 2020, 2021]
df = pd.DataFrame(data, columns=columns)
df
# Out:
#     Category Factor     2020     2021
# 0  Multiples    PER    21.09    13.55
# 1  Multiples    PBR     2.06     1.80
# 2  Dividends    DPS  2944.00  1444.00
# 3  Dividends   배당성향    78.00    25.00

# %%
#2. DataFrame.set_index (멀티인덱스) - 열의 이름으로 인덱스하기
#위 데이터프레임에서 set_index 메서드를 사용해서 'Category' 컬럼과 'Factor' 컬럼을 MultiIndex로 설정하세요.
df=df.set_index(['Category', 'Factor'])
df
# Out:
#                      2020     2021
# Category  Factor
# Multiples PER       21.09    13.55
#           PBR        2.06     1.80
# Dividends DPS     2944.00  1444.00
#           배당성향      78.00    25.00

# %%
#3. pandas.MultiIndex.from_tuples (로우방향 저장)
#MultiIndex의 from_tuples 메서드를 사용해서 tuples를 MultiIndex 객체로 생성하세요. 멀티 인덱스의 이름은 ['number','color'] 로 지정하세요.
tuples = [
    ('Multiples', 'PER'),
    ('Multiples', 'PBR'),
    ('Dividends', 'DPS'),
    ('Dividends', '배당성향')
]
index = pd.MultiIndex.from_tuples(tuples, names=['Category', 'Factor'])
df
# Out:
#                      2020     2021
# Category  Factor
# Multiples PER       21.09    13.55
#           PBR        2.06     1.80
# Dividends DPS     2944.00  1444.00
#           배당성향      78.00    25.00

# %%
#4. pandas.MultiIndex.from_arrays (컬럼방향 저장)
#MultiIndex의 from_arrays 메서드를 사용해서 파이썬 이중 리스트를 MultiIndex 객체로 생성하세요. 멀티 인덱스의 이름은 ['number', 'color']​로 지정하세요.
arrays = [
    ['Mutiples', 'Multiples', 'Dividends', 'Dividends'],
    ['PER', 'PBR', 'DPS', '배당성향']
]
index = pd.MultiIndex.from_arrays(arrays,  names=['Category', 'Factor'])
df
# Out:
#                      2020     2021
# Category  Factor
# Multiples PER       21.09    13.55
#           PBR        2.06     1.80
# Dividends DPS     2944.00  1444.00
#           배당성향      78.00    25.00

# %%
#5
import pandas as pd
tuples = [
    ('Multiples', 'PER'),
    ('Multiples', 'PBR'),
    ('Dividends', 'DPS'),
    ('Dividends', '배당성향')
]

data = [
    [21.09, 13.55],
    [2.06, 1.80],
    [2944, 1444],
    [78, 25]
]

columns = [2020, 2021]
df
# Out:
#                      2020     2021
# Category  Factor
# Multiples PER       21.09    13.55
#           PBR        2.06     1.80
# Dividends DPS     2944.00  1444.00
#           배당성향      78.00    25.00

# %%
#6 빨강색 영역 선택
df.loc['Multiples']
# Out:
#          2020   2021
# Factor
# PER     21.09  13.55
# PBR      2.06   1.80

# %%
#7. pandas.MultiIndex 인덱싱
#위 데이터프레임에서 loc 속성을 이용해 Multiples의 PER 로우만 선택하세요.
df.loc [ ('Multiples','PER') ]
# Out:
# 2020    21.09
# 2021    13.55
# Name: (Multiples, PER), dtype: float64

# %%
#8. pandas.MultiIndex 인덱싱 (iloc)
#위 데이터프레임에서 iloc 속성을 이용해 Multiples의 PER 로우만 선택하세요.
df.iloc[  0  ] #0번 인덱스
# Out:
# 2020    21.09
# 2021    13.55
# Name: (Multiples, PER), dtype: float64

# %%
#9. pandas.MultiIndex 인덱싱 loc
#위 데이터프레임에서 loc 속성을 사용하여 2020년 PER 값을 출력해보세요.
df.loc [  ( 'Multiples','PER'  ), 2020  ]
# Out:
# 21.09

# %%
#10. DataFrame.sort_index
#위 데이터프레임을 sort_index 메서드를 사용해서 인덱스를 정렬하세요.
df.sort_index()
# Out:
#                      2020     2021
# Category  Factor
# Dividends DPS     2944.00  1444.00
#           배당성향      78.00    25.00
# Multiples PBR        2.06     1.80
#           PER       21.09    13.55

# %%
iris_url=' https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
iris_df = pd.read.csv(iris_url, sep=',', encoding='cp949' )
iris_df.set_index=( [ id ] )
iris_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-530f799b0748> in <cell line: 2>()
#       1 iris_url=' https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
# ----> 2 iris_df = pd.read.csv(iris_url, sep=',', encoding='cp949' )
#       3 iris_df.set_index=( [ id ] )
#       4 iris_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'read'
